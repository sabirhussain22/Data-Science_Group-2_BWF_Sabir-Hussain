# %% [markdown]
# # Task 12: Introduction to Pandas (Series, DataFrame basics)

# %% [markdown]
# # Introduction to Pandas
#
# Pandas is a powerful and flexible open-source data analysis and manipulation library for Python. It provides data structures like Series and DataFrame, which make it easy to handle structured data, perform operations, and visualize data efficiently.
#
# ## Key Data Structures
# ### Series
# A Series is a one-dimensional labeled array capable of holding any data type. It is similar to a column in a table or a list in Python but with additional features.
# ### DataFrame
# A DataFrame is a two-dimensional labeled data structure with columns of potentially different types. It is similar to a table in a database or a spreadsheet in Excel.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Create a Pandas Series from a Python list, numpy array, and a dictionary.

# %%
python_list = [10, 20, 30, 40, 50]

series_from_list = pd.Series(python_list)
print("Series from Python list:")
print(series_from_list)

numpy_array = np.array([10, 20, 30, 40, 50])

series_from_array = pd.Series(numpy_array)
print("\nSeries from NumPy array:")
print(series_from_array)

data_dict = {'A': 10, 'B': 20, 'C': 30, 'D': 40, 'E': 50}

series_from_dict = pd.Series(data_dict)
print("\nSeries from dictionary with custom index:")
print(series_from_dict)
# Out:
# Series from Python list:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
#
# Series from NumPy array:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int32
#
# Series from dictionary with custom index:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %% [markdown]
# #### Assign a custom index to the Series.

# %%
data = [10, 20, 30, 40, 50]

custom_index = ['A', 'B', 'C', 'D', 'E']

series_with_custom_index = pd.Series(data, index=custom_index)
print("Series with custom index:")
print(series_with_custom_index)
# Out:
# Series with custom index:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %% [markdown]
# #### Perform basic arithmetic operations on Series.

# %%
s1 = pd.Series([1, 2, 3, 4])
s2 = pd.Series([10, 20, 30, 40])

addition = s1 + s2
print("\nAddition of two Series:")
print(addition)

subtraction = s2 - s1
print("\nSubtraction of two Series:")
print(subtraction)

multiplication = s1 * s2
print("\nMultiplication of two Series:")
print(multiplication)

division = s2 / s1
print("\nDivision of two Series:")
print(division)
# Out:
# Addition of two Series:
# 0    11
# 1    22
# 2    33
# 3    44
# dtype: int64
#
# Subtraction of two Series:
# 0     9
# 1    18
# 2    27
# 3    36
# dtype: int64
#
# Multiplication of two Series:
# 0     10
# 1     40
# 2     90
# 3    160
# dtype: int64
#
# Division of two Series:
# 0    10.0
# 1    10.0
# 2    10.0
# 3    10.0
# dtype: float64

# %% [markdown]
# #### Access elements using index labels and positions.

# %%
print("\nAccessing element at label 'B':", series_from_dict['B'])

print("Accessing element at position 2:", series_from_dict.iloc[2])
# Out:
# Accessing element at label 'B': 20
# Accessing element at position 2: 30

# %% [markdown]
# #### Filter the Series to include only values greater than a specific threshold.

# %%
filtered_series = series_from_dict[series_from_dict > 30]
print("\nFiltered Series with values greater than 30:")
print(filtered_series)
# Out:
# Filtered Series with values greater than 30:
# D    40
# E    50
# dtype: int64

# %% [markdown]
# #### Create a DataFrame from a dictionary of lists.

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}

df_from_dict = pd.DataFrame(data)
print("\nDataFrame from dictionary of lists:")
print(df_from_dict)
# Out:
# DataFrame from dictionary of lists:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %% [markdown]
# #### Create a DataFrame from a numpy array, specifying column and index names.

# %%
numpy_data = np.array([
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
])

df_from_numpy = pd.DataFrame(numpy_data, columns=['A', 'B', 'C'], index=['X', 'Y', 'Z'])
print("\nDataFrame from NumPy array with column and index names:")
print(df_from_numpy)
# Out:
# DataFrame from NumPy array with column and index names:
#     A   B   C
# X  10  20  30
# Y  40  50  60
# Z  70  80  90

# %% [markdown]
# #### Load a DataFrame from a CSV file.

# %%
df = pd.read_csv("laptop_price_data.csv")
df
# Out:
#      Company            TypeName  Ram  Weight      Price  TouchScreen  Ips  \
# 0      Apple           Ultrabook    8    1.37  11.175755            0    1
# 1      Apple           Ultrabook    8    1.34  10.776777            0    0
# 2         HP            Notebook    8    1.86  10.329931            0    0
# 3      Apple           Ultrabook   16    1.83  11.814476            0    1
# 4      Apple           Ultrabook    8    1.37  11.473101            0    1
# ...      ...                 ...  ...     ...        ...          ...  ...
# 1268    Asus            Notebook    4    2.20  10.555257            0    0
# 1269  Lenovo  2 in 1 Convertible    4    1.80  10.433899            1    1
# 1270  Lenovo  2 in 1 Convertible   16    1.30  11.288115            1    1
# 1271  Lenovo            Notebook    2    1.50   9.409283            0    0
# 1272      HP            Notebook    6    2.19  10.614129            0    0
#
#              Ppi              Cpu_brand   HDD  SSD Gpu_brand       Os
# 0     226.983005          Intel Core i5     0  128     Intel      Mac
# 1     127.677940          Intel Core i5     0    0     Intel      Mac
# 2     141.211998          Intel Core i5     0  256     Intel   Others
# 3     220.534624          Intel Core i7     0  512       AMD      Mac
# 4     226.983005          Intel Core i5     0  256     Intel      Mac
# ...          ...                    ...   ...  ...       ...      ...
# 1268  100.454670          Intel Core i7   500    0    Nvidia  Windows
# 1269  157.350512          Intel Core i7     0  128     Intel  Windows
# 1270  276.053530          Intel Core i7     0  512     Intel  Windows
# 1271  111.935204  Other Intel Processor     0    0     Intel  Windows
# 1272  100.454670          Intel Core i7  1000    0       AMD  Windows
#
# [1273 rows x 13 columns]

# %% [markdown]
# #### Display the first and last five rows of the DataFrame.

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight      Price  TouchScreen  Ips         Ppi  \
# 0   Apple  Ultrabook    8    1.37  11.175755            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34  10.776777            0    0  127.677940
# 2      HP   Notebook    8    1.86  10.329931            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  11.814476            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37  11.473101            0    1  226.983005
#
#        Cpu_brand  HDD  SSD Gpu_brand      Os
# 0  Intel Core i5    0  128     Intel     Mac
# 1  Intel Core i5    0    0     Intel     Mac
# 2  Intel Core i5    0  256     Intel  Others
# 3  Intel Core i7    0  512       AMD     Mac
# 4  Intel Core i5    0  256     Intel     Mac

# %%
df.tail()
# Out:
#      Company            TypeName  Ram  Weight      Price  TouchScreen  Ips  \
# 1268    Asus            Notebook    4    2.20  10.555257            0    0
# 1269  Lenovo  2 in 1 Convertible    4    1.80  10.433899            1    1
# 1270  Lenovo  2 in 1 Convertible   16    1.30  11.288115            1    1
# 1271  Lenovo            Notebook    2    1.50   9.409283            0    0
# 1272      HP            Notebook    6    2.19  10.614129            0    0
#
#              Ppi              Cpu_brand   HDD  SSD Gpu_brand       Os
# 1268  100.454670          Intel Core i7   500    0    Nvidia  Windows
# 1269  157.350512          Intel Core i7     0  128     Intel  Windows
# 1270  276.053530          Intel Core i7     0  512     Intel  Windows
# 1271  111.935204  Other Intel Processor     0    0     Intel  Windows
# 1272  100.454670          Intel Core i7  1000    0       AMD  Windows

# %% [markdown]
# #### Get a summary of the DataFrame including the mean, median, and standard deviation of numeric columns.

# %%
df.describe()
# Out:
#                Ram       Weight        Price  TouchScreen          Ips  \
# count  1273.000000  1273.000000  1273.000000  1273.000000  1273.000000
# mean      8.447761     2.041100    10.828218     0.146897     0.279654
# std       5.098771     0.669241     0.619565     0.354142     0.449006
# min       2.000000     0.690000     9.134616     0.000000     0.000000
# 25%       4.000000     1.500000    10.387379     0.000000     0.000000
# 50%       8.000000     2.040000    10.872255     0.000000     0.000000
# 75%       8.000000     2.310000    11.287447     0.000000     1.000000
# max      64.000000     4.700000    12.691441     1.000000     1.000000
#
#                Ppi          HDD          SSD
# count  1273.000000  1273.000000  1273.000000
# mean    146.950812   413.715632   186.252946
# std      42.926775   518.054486   186.531571
# min      90.583402     0.000000     0.000000
# 25%     127.335675     0.000000     0.000000
# 50%     141.211998     0.000000   256.000000
# 75%     157.350512  1000.000000   256.000000
# max     352.465147  2000.000000  1024.000000

# %%
Companies = df['Company']
print("\nSeries extracted from 'Company' column:")
print(Companies)
# Out:
# Series extracted from 'Company' column:
# 0        Apple
# 1        Apple
# 2           HP
# 3        Apple
# 4        Apple
#          ...
# 1268      Asus
# 1269    Lenovo
# 1270    Lenovo
# 1271    Lenovo
# 1272        HP
# Name: Company, Length: 1273, dtype: object

# %% [markdown]
# #### Filter rows based on column values.

# %%
filtered_df = df[df['Company'] == 'Lenovo']
filtered_df
# Out:
#      Company            TypeName  Ram  Weight      Price  TouchScreen  Ips  \
# 18    Lenovo            Notebook    8    2.20  10.188167            0    0
# 21    Lenovo              Gaming    8    2.50  10.882316            0    1
# 35    Lenovo            Notebook    4    1.44   9.493014            0    0
# 46    Lenovo            Notebook    4    2.20   9.886358            0    0
# 50    Lenovo  2 in 1 Convertible    4    0.69   9.740752            1    1
# ...      ...                 ...  ...     ...        ...          ...  ...
# 1259  Lenovo  2 in 1 Convertible    4    1.80  10.700607            1    0
# 1264  Lenovo            Notebook    8    2.60  10.776844            0    1
# 1269  Lenovo  2 in 1 Convertible    4    1.80  10.433899            1    1
# 1270  Lenovo  2 in 1 Convertible   16    1.30  11.288115            1    1
# 1271  Lenovo            Notebook    2    1.50   9.409283            0    0
#
#              Ppi              Cpu_brand   HDD  SSD Gpu_brand       Os
# 18    141.211998          Intel Core i3  1000    0    Nvidia   Others
# 21    141.211998          Intel Core i5  1000  128    Nvidia  Windows
# 35    111.935204  Other Intel Processor     0    0     Intel  Windows
# 46    100.454670          Intel Core i3     0  128     Intel   Others
# 50    224.173809  Other Intel Processor     0    0     Intel   Others
# ...          ...                    ...   ...  ...       ...      ...
# 1259  157.350512          Intel Core i5     0  128     Intel  Windows
# 1264  141.211998          Intel Core i7  1000    0    Nvidia  Windows
# 1269  157.350512          Intel Core i7     0  128     Intel  Windows
# 1270  276.053530          Intel Core i7     0  512     Intel  Windows
# 1271  111.935204  Other Intel Processor     0    0     Intel  Windows
#
# [289 rows x 13 columns]

# %%
average_price = df['Price'].mean()
filtered_df = df[df['Price'] > average_price]
filtered_df
# Out:
#      Company            TypeName  Ram  Weight      Price  TouchScreen  Ips  \
# 0      Apple           Ultrabook    8    1.37  11.175755            0    1
# 3      Apple           Ultrabook   16    1.83  11.814476            0    1
# 4      Apple           Ultrabook    8    1.37  11.473101            0    1
# 6      Apple           Ultrabook   16    2.04  11.644108            0    1
# 7      Apple           Ultrabook    8    1.34  11.030615            0    0
# ...      ...                 ...  ...     ...        ...          ...  ...
# 1248    Dell  2 in 1 Convertible    8    1.24  11.478299            1    0
# 1252  Lenovo            Notebook    8    1.90  10.952842            0    1
# 1255    Asus              Gaming   16    4.00  11.525170            0    1
# 1258     MSI              Gaming    8    2.40  11.089517            0    0
# 1270  Lenovo  2 in 1 Convertible   16    1.30  11.288115            1    1
#
#              Ppi      Cpu_brand   HDD  SSD Gpu_brand       Os
# 0     226.983005  Intel Core i5     0  128     Intel      Mac
# 3     220.534624  Intel Core i7     0  512       AMD      Mac
# 4     226.983005  Intel Core i5     0  256     Intel      Mac
# 6     220.534624  Intel Core i7     0    0     Intel      Mac
# 7     127.677940  Intel Core i5     0    0     Intel      Mac
# ...          ...            ...   ...  ...       ...      ...
# 1248  276.053530  Intel Core i5     0  256     Intel  Windows
# 1252  157.350512  Intel Core i5     0  256     Intel  Windows
# 1255  127.335675  Intel Core i7  1000  128    Nvidia  Windows
# 1258  141.211998  Intel Core i7  1000  128    Nvidia  Windows
# 1270  276.053530  Intel Core i7     0  512     Intel  Windows
#
# [673 rows x 13 columns]

# %% [markdown]
# #### Select rows based on multiple conditions.

# %%
apple_laptops_with_high_ram = df[(df['Company'] == 'Apple') & (df['Ram'] > 8)]
apple_laptops_with_high_ram
# Out:
#    Company   TypeName  Ram  Weight      Price  TouchScreen  Ips         Ppi  \
# 3    Apple  Ultrabook   16    1.83  11.814476            0    1  220.534624
# 6    Apple  Ultrabook   16    2.04  11.644108            0    1  220.534624
# 12   Apple  Ultrabook   16    1.83  11.775302            0    1  220.534624
# 17   Apple  Ultrabook   16    1.83  11.933438            0    1  220.534624
#
#         Cpu_brand  HDD  SSD Gpu_brand   Os
# 3   Intel Core i7    0  512       AMD  Mac
# 6   Intel Core i7    0    0     Intel  Mac
# 12  Intel Core i7    0  256       AMD  Mac
# 17  Intel Core i7    0  512       AMD  Mac

# %%
cheap_touchscreen_laptops = df[(df['Price'] < 10) & (df['TouchScreen'] == 1)]
cheap_touchscreen_laptops
# Out:
#       Company            TypeName  Ram  Weight     Price  TouchScreen  Ips  \
# 50     Lenovo  2 in 1 Convertible    4    0.69  9.740752            1    1
# 314      Asus  2 in 1 Convertible    2    1.10  9.592332            1    0
# 348      Asus  2 in 1 Convertible    4    1.50  9.902487            1    0
# 429  Mediacom  2 in 1 Convertible    4    1.16  9.676005            1    1
# 560      Acer  2 in 1 Convertible    4    1.25  9.830633            1    1
# 619      Acer  2 in 1 Convertible    4    1.25  9.913097            1    1
# 959      Acer  2 in 1 Convertible    4    1.25  9.939140            1    1
#
#             Ppi              Cpu_brand  HDD  SSD Gpu_brand       Os
# 50   224.173809  Other Intel Processor    0    0     Intel   Others
# 314  135.094211  Other Intel Processor    0    0     Intel  Windows
# 348  135.094211  Other Intel Processor    0    0     Intel  Windows
# 429  189.905791  Other Intel Processor    0   32     Intel  Windows
# 560  189.905791  Other Intel Processor    0    0     Intel  Windows
# 619  135.094211  Other Intel Processor    0    0     Intel   Others
# 959  135.094211  Other Intel Processor    0    0     Intel   Others

# %% [markdown]
# #### Add a new column to the DataFrame.

# %%
df['Storage'] = df['HDD'] + df['SSD']
df.head()
# Out:
#   Company   TypeName  Ram  Weight      Price  TouchScreen  Ips         Ppi  \
# 0   Apple  Ultrabook    8    1.37  11.175755            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34  10.776777            0    0  127.677940
# 2      HP   Notebook    8    1.86  10.329931            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  11.814476            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37  11.473101            0    1  226.983005
#
#        Cpu_brand  HDD  SSD Gpu_brand      Os  Storage
# 0  Intel Core i5    0  128     Intel     Mac      128
# 1  Intel Core i5    0    0     Intel     Mac        0
# 2  Intel Core i5    0  256     Intel  Others      256
# 3  Intel Core i7    0  512       AMD     Mac      512
# 4  Intel Core i5    0  256     Intel     Mac      256

# %% [markdown]
# #### Delete a column from the DataFrame.

# %%
df = df.drop(columns=['Ips'])
df.head()
# Out:
#   Company   TypeName  Ram  Weight      Price  TouchScreen         Ppi  \
# 0   Apple  Ultrabook    8    1.37  11.175755            0  226.983005
# 1   Apple  Ultrabook    8    1.34  10.776777            0  127.677940
# 2      HP   Notebook    8    1.86  10.329931            0  141.211998
# 3   Apple  Ultrabook   16    1.83  11.814476            0  220.534624
# 4   Apple  Ultrabook    8    1.37  11.473101            0  226.983005
#
#        Cpu_brand  HDD  SSD Gpu_brand      Os  Storage
# 0  Intel Core i5    0  128     Intel     Mac      128
# 1  Intel Core i5    0    0     Intel     Mac        0
# 2  Intel Core i5    0  256     Intel  Others      256
# 3  Intel Core i7    0  512       AMD     Mac      512
# 4  Intel Core i5    0  256     Intel     Mac      256

# %% [markdown]
# #### Rename columns in the DataFrame.

# %%
df = df.rename(columns={'TypeName': 'Type', 'Cpu_brand': 'CPU'})
df.head()
# Out:
#   Company       Type  Ram  Weight      Price  TouchScreen         Ppi  \
# 0   Apple  Ultrabook    8    1.37  11.175755            0  226.983005
# 1   Apple  Ultrabook    8    1.34  10.776777            0  127.677940
# 2      HP   Notebook    8    1.86  10.329931            0  141.211998
# 3   Apple  Ultrabook   16    1.83  11.814476            0  220.534624
# 4   Apple  Ultrabook    8    1.37  11.473101            0  226.983005
#
#              CPU  HDD  SSD Gpu_brand      Os  Storage
# 0  Intel Core i5    0  128     Intel     Mac      128
# 1  Intel Core i5    0    0     Intel     Mac        0
# 2  Intel Core i5    0  256     Intel  Others      256
# 3  Intel Core i7    0  512       AMD     Mac      512
# 4  Intel Core i5    0  256     Intel     Mac      256
