# %% [markdown]
# # Task 14: Data cleaning and preprocessing with Pandas

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import PolynomialFeatures

# %%
df = pd.read_csv('Titanic_Data.csv')
df
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1             c         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# ..          ...       ...     ...
# 416        1308         0       3
# 417        1309         0       3
# 418         895         0       3
# 419        1304         1       3
# 420        1020         0       2
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421 entries, 0 to 420
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  421 non-null    object
#  1   Survived     421 non-null    int64
#  2   Pclass       421 non-null    int64
#  3   Name         421 non-null    object
#  4   Sex          421 non-null    object
#  5   Age          335 non-null    float64
#  6   SibSp        421 non-null    int64
#  7   Parch        421 non-null    int64
#  8   Ticket       421 non-null    object
#  9   Fare         420 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     421 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 39.6+ KB

# %% [markdown]
# #### Identify missing values in the DataFrame.

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          330
# Embarked         0
# dtype: int64

# %% [markdown]
# #### Drop rows with any missing values.

# %%
df_dropna_rows = df.dropna()
df_dropna_rows
# Out:
#     PassengerId  Survived  Pclass  \
# 12          904         1       1
# 14          906         1       1
# 24          916         1       1
# 26          918         1       1
# 28          920         0       1
# ..          ...       ...     ...
# 404        1296         0       1
# 405        1297         0       2
# 407        1299         0       1
# 411        1303         1       1
# 414        1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### Drop columns with any missing values.

# %%
df_dropna_cols = df.dropna(axis=1)
df_dropna_cols
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1             c         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# ..          ...       ...     ...
# 416        1308         0       3
# 417        1309         0       3
# 418         895         0       3
# 419        1304         1       3
# 420        1020         0       2
#
#                                              Name     Sex  SibSp  Parch  \
# 0                                Kelly, Mr. James    male      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female      1      0
# 2                       Myles, Mr. Thomas Francis    male      0      0
# 3                                Wirz, Mr. Albert    male      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female      1      1
# ..                                            ...     ...    ...    ...
# ...

# %% [markdown]
# #### Fill missing values with a specific value.

# %%
df_filled = df.fillna(0)
df_filled
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1             c         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# ..          ...       ...     ...
# 416        1308         0       3
# 417        1309         0       3
# 418         895         0       3
# 419        1304         1       3
# 420        1020         0       2
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# ...

# %%
df_filled.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# #### Fill missing values using forward fill and backward fill methods.

# %%
df_ffill = df.fillna(method='ffill')
df_ffill
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17816\2606470401.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill = df.fillna(method='ffill')
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1             c         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# ..          ...       ...     ...
# 416        1308         0       3
# 417        1309         0       3
# 418         895         0       3
# 419        1304         1       3
# 420        1020         0       2
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# ...

# %%
df_bfill = df.fillna(method='bfill')
df_bfill
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17816\816406448.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_bfill = df.fillna(method='bfill')
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1             c         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# ..          ...       ...     ...
# 416        1308         0       3
# 417        1309         0       3
# 418         895         0       3
# 419        1304         1       3
# 420        1020         0       2
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# ...

# %% [markdown]
# #### Interpolate missing values.

# %%
df_interpolated = df.interpolate()
df_interpolated
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17816\130634364.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df_interpolated = df.interpolate()
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1             c         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# ..          ...       ...     ...
# 416        1308         0       3
# 417        1309         0       3
# 418         895         0       3
# 419        1304         1       3
# 420        1020         0       2
#
#                                              Name     Sex        Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.500000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.000000      1
# ...

# %% [markdown]
# #### Convert a column to a different data type.

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
df['Age'] = df['Age'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421 entries, 0 to 420
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  421 non-null    object
#  1   Survived     421 non-null    int64
#  2   Pclass       421 non-null    int64
#  3   Name         421 non-null    object
#  4   Sex          421 non-null    object
#  5   Age          421 non-null    int32
#  6   SibSp        421 non-null    int64
#  7   Parch        421 non-null    int64
#  8   Ticket       421 non-null    object
#  9   Fare         420 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     421 non-null    object
# dtypes: float64(1), int32(1), int64(4), object(6)
# memory usage: 38.0+ KB

# %% [markdown]
# #### Apply a function to transform the values of a column.

# %%
def replace_sex(sex):
    if sex == 'male':
        return 'm'
    elif sex == 'female':
        return 'f'
    return sex

# %%
df['Sex'].apply(replace_sex)
# Out:
# 0      m
# 1      f
# 2      m
# 3      m
# 4      f
#       ..
# 416    m
# 417    m
# 418    m
# 419    f
# 420    m
# Name: Sex, Length: 421, dtype: object

# %% [markdown]
# #### Normalize a column using Min-Max scaling.

# %%
df['Fare_normalized'] = (df['Fare'] - df['Fare'].min()) / (df['Fare'].max() - df['Fare'].min())
df
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1             c         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# ..          ...       ...     ...
# 416        1308         0       3
# 417        1309         0       3
# 418         895         0       3
# 419        1304         1       3
# 420        1020         0       2
#
#                                              Name     Sex  Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male   34      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female   47      1      0
# 2                       Myles, Mr. Thomas Francis    male   62      0      0
# 3                                Wirz, Mr. Albert    male   27      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female   22      1      1
# ..                                            ...     ...  ...    ...    ...
# ...

# %% [markdown]
# #### Standardize a column (z-score normalization).

# %%
df['Fare_scaled'] = (df['Fare'] - df['Fare'].mean()) / df['Fare'].std()
df
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1             c         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# ..          ...       ...     ...
# 416        1308         0       3
# 417        1309         0       3
# 418         895         0       3
# 419        1304         1       3
# 420        1020         0       2
#
#                                              Name     Sex  Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male   34      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female   47      1      0
# 2                       Myles, Mr. Thomas Francis    male   62      0      0
# 3                                Wirz, Mr. Albert    male   27      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female   22      1      1
# ..                                            ...     ...  ...    ...    ...
# ...

# %% [markdown]
# #### Identify duplicate rows in the DataFrame.

# %%
duplicates = df.duplicated()
print(duplicates.sum())
# Out:
# 4

# %% [markdown]
# #### Drop duplicate rows.

# %%
df_no_duplicates = df.drop_duplicates()

# %% [markdown]
# #### Drop duplicate rows based on specific columns.

# %%
df_no_duplicates_subset = df.drop_duplicates(subset=['Age', 'Sex'])

# %% [markdown]
# #### Convert all string values in a column to lowercase.

# %%
df['Name'] = df['Name'].str.lower()
df
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1             c         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# ..          ...       ...     ...
# 416        1308         0       3
# 417        1309         0       3
# 418         895         0       3
# 419        1304         1       3
# 420        1020         0       2
#
#                                              Name     Sex  Age  SibSp  Parch  \
# 0                                kelly, mr. james    male   34      0      0
# 1                wilkes, mrs. james (ellen needs)  female   47      1      0
# 2                       myles, mr. thomas francis    male   62      0      0
# 3                                wirz, mr. albert    male   27      0      0
# 4    hirvonen, mrs. alexander (helga e lindqvist)  female   22      1      1
# ..                                            ...     ...  ...    ...    ...
# ...

# %% [markdown]
# #### Remove leading and trailing spaces from string values in a column.

# %%
df['Name'] = df['Name'].str.strip()
df.head()
# Out:
#   PassengerId  Survived  Pclass                                          Name  \
# 0         892         0       3                              kelly, mr. james
# 1           c         1       3              wilkes, mrs. james (ellen needs)
# 2         894         0       2                     myles, mr. thomas francis
# 3         895         0       3                              wirz, mr. albert
# 4         896         1       3  hirvonen, mrs. alexander (helga e lindqvist)
#
#       Sex  Age  SibSp  Parch   Ticket     Fare Cabin Embarked  \
# 0    male   34      0      0   330911   7.8292   NaN        Q
# 1  female   47      1      0   363272   7.0000   NaN        S
# 2    male   62      0      0   240276   9.6875   NaN        Q
# 3    male   27      0      0   315154   8.6625   NaN        S
# 4  female   22      1      1  3101298  12.2875   NaN        S
#
#    Fare_normalized  Fare_scaled
# 0         0.015282    -0.494792
# 1         0.013663    -0.509664
# ...

# %% [markdown]
# #### Replace a specific substring in a column with another substring.

# %%
df['Sex'] = df['Sex'].str.replace('female', 'F')
df.head()
# Out:
#   PassengerId  Survived  Pclass                                          Name  \
# 0         892         0       3                              kelly, mr. james
# 1           c         1       3              wilkes, mrs. james (ellen needs)
# 2         894         0       2                     myles, mr. thomas francis
# 3         895         0       3                              wirz, mr. albert
# 4         896         1       3  hirvonen, mrs. alexander (helga e lindqvist)
#
#     Sex  Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Fare_normalized  \
# 0  male   34      0      0   330911   7.8292   NaN        Q         0.015282
# 1     F   47      1      0   363272   7.0000   NaN        S         0.013663
# 2  male   62      0      0   240276   9.6875   NaN        Q         0.018909
# 3  male   27      0      0   315154   8.6625   NaN        S         0.016908
# 4     F   22      1      1  3101298  12.2875   NaN        S         0.023984
#
#    Fare_scaled
# 0    -0.494792
# ...

# %% [markdown]
# #### Extract a substring from each value in a column.

# %%
df['cabin_section'] = df['Cabin'].str[:1]
df.head()
# Out:
#   PassengerId  Survived  Pclass                                          Name  \
# 0         892         0       3                              kelly, mr. james
# 1           c         1       3              wilkes, mrs. james (ellen needs)
# 2         894         0       2                     myles, mr. thomas francis
# 3         895         0       3                              wirz, mr. albert
# 4         896         1       3  hirvonen, mrs. alexander (helga e lindqvist)
#
#     Sex  Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Fare_normalized  \
# 0  male   34      0      0   330911   7.8292   NaN        Q         0.015282
# 1     F   47      1      0   363272   7.0000   NaN        S         0.013663
# 2  male   62      0      0   240276   9.6875   NaN        Q         0.018909
# 3  male   27      0      0   315154   8.6625   NaN        S         0.016908
# 4     F   22      1      1  3101298  12.2875   NaN        S         0.023984
#
#    Fare_scaled cabin_section
# ...

# %% [markdown]
# #### Convert a column to datetime format.

# %%
df['synthetic_date'] = pd.to_datetime('2024-01-01')
df.head()
# Out:
#   PassengerId  Survived  Pclass                                          Name  \
# 0         892         0       3                              kelly, mr. james
# 1           c         1       3              wilkes, mrs. james (ellen needs)
# 2         894         0       2                     myles, mr. thomas francis
# 3         895         0       3                              wirz, mr. albert
# 4         896         1       3  hirvonen, mrs. alexander (helga e lindqvist)
#
#     Sex  Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Fare_normalized  \
# 0  male   34      0      0   330911   7.8292   NaN        Q         0.015282
# 1     F   47      1      0   363272   7.0000   NaN        S         0.013663
# 2  male   62      0      0   240276   9.6875   NaN        Q         0.018909
# 3  male   27      0      0   315154   8.6625   NaN        S         0.016908
# 4     F   22      1      1  3101298  12.2875   NaN        S         0.023984
#
# ...

# %% [markdown]
# #### Extract year, month, and day from a datetime column.

# %%
df['year'] = df['synthetic_date'].dt.year
df['month'] = df['synthetic_date'].dt.month
df['day'] = df['synthetic_date'].dt.day
df.head()
# Out:
#   PassengerId  Survived  Pclass                                          Name  \
# 0         892         0       3                              kelly, mr. james
# 1           c         1       3              wilkes, mrs. james (ellen needs)
# 2         894         0       2                     myles, mr. thomas francis
# 3         895         0       3                              wirz, mr. albert
# 4         896         1       3  hirvonen, mrs. alexander (helga e lindqvist)
#
#     Sex  Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Fare_normalized  \
# 0  male   34      0      0   330911   7.8292   NaN        Q         0.015282
# 1     F   47      1      0   363272   7.0000   NaN        S         0.013663
# 2  male   62      0      0   240276   9.6875   NaN        Q         0.018909
# 3  male   27      0      0   315154   8.6625   NaN        S         0.016908
# 4     F   22      1      1  3101298  12.2875   NaN        S         0.023984
#
# ...

# %% [markdown]
# #### Filter rows based on a date range.

# %%
date_filtered = df[(df['synthetic_date'] > '2023-01-01') & (df['synthetic_date'] < '2024-12-31')]
date_filtered.head()
# Out:
#   PassengerId  Survived  Pclass                                          Name  \
# 0         892         0       3                              kelly, mr. james
# 1           c         1       3              wilkes, mrs. james (ellen needs)
# 2         894         0       2                     myles, mr. thomas francis
# 3         895         0       3                              wirz, mr. albert
# 4         896         1       3  hirvonen, mrs. alexander (helga e lindqvist)
#
#     Sex  Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Fare_normalized  \
# 0  male   34      0      0   330911   7.8292   NaN        Q         0.015282
# 1     F   47      1      0   363272   7.0000   NaN        S         0.013663
# 2  male   62      0      0   240276   9.6875   NaN        Q         0.018909
# 3  male   27      0      0   315154   8.6625   NaN        S         0.016908
# 4     F   22      1      1  3101298  12.2875   NaN        S         0.023984
#
# ...

# %% [markdown]
# #### Convert a categorical column to numerical using one hot encoding.

# %%
df = pd.get_dummies(df, columns=['Sex'])
df.head()
# Out:
#   PassengerId  Survived  Pclass                                          Name  \
# 0         892         0       3                              kelly, mr. james
# 1           c         1       3              wilkes, mrs. james (ellen needs)
# 2         894         0       2                     myles, mr. thomas francis
# 3         895         0       3                              wirz, mr. albert
# 4         896         1       3  hirvonen, mrs. alexander (helga e lindqvist)
#
#    Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Fare_normalized  \
# 0   34      0      0   330911   7.8292   NaN        Q         0.015282
# 1   47      1      0   363272   7.0000   NaN        S         0.013663
# 2   62      0      0   240276   9.6875   NaN        Q         0.018909
# 3   27      0      0   315154   8.6625   NaN        S         0.016908
# 4   22      1      1  3101298  12.2875   NaN        S         0.023984
#
# ...

# %% [markdown]
# #### Convert a categorical column to numerical using label encoding.

# %%
le = LabelEncoder()
df['Embarked'] = le.fit_transform(df['Embarked'].astype(str))
df
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1             c         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# ..          ...       ...     ...
# 416        1308         0       3
# 417        1309         0       3
# 418         895         0       3
# 419        1304         1       3
# 420        1020         0       2
#
#                                              Name  Age  SibSp  Parch   Ticket  \
# 0                                kelly, mr. james   34      0      0   330911
# 1                wilkes, mrs. james (ellen needs)   47      1      0   363272
# 2                       myles, mr. thomas francis   62      0      0   240276
# 3                                wirz, mr. albert   27      0      0   315154
# 4    hirvonen, mrs. alexander (helga e lindqvist)   22      1      1  3101298
# ..                                            ...  ...    ...    ...      ...
# ...

# %% [markdown]
# #### Group values in a categorical column and create a new column with grouped categories.

# %%
df['age_group'] = pd.cut(df['Age'], bins=[0, 18, 40, 60, 80], labels=['Child', 'Adult', 'Middle-aged', 'Senior'])
df.head()
# Out:
#   PassengerId  Survived  Pclass                                          Name  \
# 0         892         0       3                              kelly, mr. james
# 1           c         1       3              wilkes, mrs. james (ellen needs)
# 2         894         0       2                     myles, mr. thomas francis
# 3         895         0       3                              wirz, mr. albert
# 4         896         1       3  hirvonen, mrs. alexander (helga e lindqvist)
#
#    Age  SibSp  Parch   Ticket     Fare Cabin  ...  Fare_normalized  \
# 0   34      0      0   330911   7.8292   NaN  ...         0.015282
# 1   47      1      0   363272   7.0000   NaN  ...         0.013663
# 2   62      0      0   240276   9.6875   NaN  ...         0.018909
# 3   27      0      0   315154   8.6625   NaN  ...         0.016908
# 4   22      1      1  3101298  12.2875   NaN  ...         0.023984
#
#    Fare_scaled  cabin_section synthetic_date  year  month  day  Sex_F  \
# ...

# %% [markdown]
# #### Merge two DataFrames based on a common column.

# %%
df_additional = pd.DataFrame({'Name': df['Name'], 'ticket_class': df['Pclass']})
merged_df = pd.merge(df, df_additional, on='Name')
merged_df.head()
# Out:
#   PassengerId  Survived  Pclass                              Name  Age  SibSp  \
# 0         892         0       3                  kelly, mr. james   34      0
# 1           c         1       3  wilkes, mrs. james (ellen needs)   47      1
# 2         894         0       2         myles, mr. thomas francis   62      0
# 3         895         0       3                  wirz, mr. albert   27      0
# 4         895         0       3                  wirz, mr. albert   27      0
#
#    Parch  Ticket    Fare Cabin  ...  Fare_scaled  cabin_section  \
# 0      0  330911  7.8292   NaN  ...    -0.494792            NaN
# 1      0  363272  7.0000   NaN  ...    -0.509664            NaN
# 2      0  240276  9.6875   NaN  ...    -0.461463            NaN
# 3      0  315154  8.6625   NaN  ...    -0.479847            NaN
# 4      0  315154  8.6625   NaN  ...    -0.479847            NaN
#
#    synthetic_date  year month  day  Sex_F  Sex_male    age_group  ticket_class
# ...

# %% [markdown]
# #### Concatenate two DataFrames vertically.

# %%
concatenated_df = pd.concat([df, df])
concatenated_df.head()
# Out:
#   PassengerId  Survived  Pclass                                          Name  \
# 0         892         0       3                              kelly, mr. james
# 1           c         1       3              wilkes, mrs. james (ellen needs)
# 2         894         0       2                     myles, mr. thomas francis
# 3         895         0       3                              wirz, mr. albert
# 4         896         1       3  hirvonen, mrs. alexander (helga e lindqvist)
#
#    Age  SibSp  Parch   Ticket     Fare Cabin  ...  Fare_normalized  \
# 0   34      0      0   330911   7.8292   NaN  ...         0.015282
# 1   47      1      0   363272   7.0000   NaN  ...         0.013663
# 2   62      0      0   240276   9.6875   NaN  ...         0.018909
# 3   27      0      0   315154   8.6625   NaN  ...         0.016908
# 4   22      1      1  3101298  12.2875   NaN  ...         0.023984
#
#    Fare_scaled  cabin_section synthetic_date  year  month  day  Sex_F  \
# ...

# %% [markdown]
# #### Concatenate two DataFrames horizontally.

# %%
concatenated_df_horizontal = pd.concat([df, df_additional], axis=1)
concatenated_df_horizontal.head()
# Out:
#   PassengerId  Survived  Pclass                                          Name  \
# 0         892         0       3                              kelly, mr. james
# 1           c         1       3              wilkes, mrs. james (ellen needs)
# 2         894         0       2                     myles, mr. thomas francis
# 3         895         0       3                              wirz, mr. albert
# 4         896         1       3  hirvonen, mrs. alexander (helga e lindqvist)
#
#    Age  SibSp  Parch   Ticket     Fare Cabin  ...  cabin_section  \
# 0   34      0      0   330911   7.8292   NaN  ...            NaN
# 1   47      1      0   363272   7.0000   NaN  ...            NaN
# 2   62      0      0   240276   9.6875   NaN  ...            NaN
# 3   27      0      0   315154   8.6625   NaN  ...            NaN
# 4   22      1      1  3101298  12.2875   NaN  ...            NaN
#
#    synthetic_date  year month day  Sex_F  Sex_male    age_group  \
# ...

# %% [markdown]
# #### Create a new column based on existing columns.

# %%
df['family_size'] = df['SibSp'] + df['Parch']
df.head()
# Out:
#   PassengerId  Survived  Pclass                                          Name  \
# 0         892         0       3                              kelly, mr. james
# 1           c         1       3              wilkes, mrs. james (ellen needs)
# 2         894         0       2                     myles, mr. thomas francis
# 3         895         0       3                              wirz, mr. albert
# 4         896         1       3  hirvonen, mrs. alexander (helga e lindqvist)
#
#    Age  SibSp  Parch   Ticket     Fare Cabin  ...  Fare_scaled  cabin_section  \
# 0   34      0      0   330911   7.8292   NaN  ...    -0.494792            NaN
# 1   47      1      0   363272   7.0000   NaN  ...    -0.509664            NaN
# 2   62      0      0   240276   9.6875   NaN  ...    -0.461463            NaN
# 3   27      0      0   315154   8.6625   NaN  ...    -0.479847            NaN
# 4   22      1      1  3101298  12.2875   NaN  ...    -0.414832            NaN
#
# ...

# %% [markdown]
# #### Discretize a continuous column into bins.

# %%
df['Age_binned'] = pd.cut(df['Age'], bins=5, labels=False)
df[['Age', 'Age_binned']]
# Out:
#      Age  Age_binned
# 0     34           2
# 1     47           3
# 2     62           4
# 3     27           1
# 4     22           1
# ..   ...         ...
# 416   30           1
# 417   30           1
# 418   27           1
# 419   28           1
# 420   42           2
#
# [421 rows x 2 columns]

# %% [markdown]
# #### Create polynomial features from existing numerical columns.

# %%
df['Fare'].fillna(df['Fare'].mean(), inplace=True)
poly = PolynomialFeatures(degree=2, include_bias=False)
fare_poly = poly.fit_transform(df[['Fare']])
columns = ['Fare', 'Fare^2']
fare_poly_df = pd.DataFrame(fare_poly, columns=columns)
fare_poly_df
# Out:
#         Fare      Fare^2
# 0     7.8292   61.296373
# 1     7.0000   49.000000
# 2     9.6875   93.847656
# 3     8.6625   75.038906
# 4    12.2875  150.982656
# ..       ...         ...
# 416   8.0500   64.802500
# 417  22.3583  499.893579
# 418   8.6625   75.038906
# 419   7.7750   60.450625
# 420  13.0000  169.000000
#
# [421 rows x 2 columns]
